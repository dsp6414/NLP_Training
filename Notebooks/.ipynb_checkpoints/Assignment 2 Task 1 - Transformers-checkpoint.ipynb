# %%
import torch
import pandas as pd
from transformers import *

# %%
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-cased-distilled-squad")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\program files\python37\lib\site-packages\tqdm\notebook.py in status_printer(_, total, desc, ncols)
#      95             if total:
# ---> 96                 pbar = IProgress(min=0, max=total)
#      97             else:  # No total? Show info style bar with no progress tqdm status
#
# NameError: name 'IProgress' is not defined
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-27ee4dddd58e> in <module>
# ----> 1 tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-cased-distilled-squad")
#
# c:\program files\python37\lib\site-packages\transformers\tokenization_utils.py in from_pretrained(cls, *inputs, **kwargs)
#     388
#     389         """
# ...

# %%
df = pd.read_csv("../Data/SICK/SICK train val transformed.csv")
sentAB = list(df["sentAB"])
len(sentAB)
# Out:
# 5000

# %%
sentAB = tokenizer.encode_plus(text=sentAB, return_tensors="pt")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-5b5d958a406e> in <module>
# ----> 1 sentAB = tokenizer.encode_plus(text=sentAB, return_tensors="pt")
#
# c:\program files\python37\lib\site-packages\transformers\tokenization_utils.py in encode_plus(self, text, text_pair, add_special_tokens, max_length, stride, truncation_strategy, pad_to_max_length, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, **kwargs)
#    1028             return_token_type_ids=return_token_type_ids,
#    1029             return_overflowing_tokens=return_overflowing_tokens,
# -> 1030             return_special_tokens_mask=return_special_tokens_mask,
#    1031         )
#    1032
#
# ...

# %%
# %debug
# Out:
# > c:\program files\python37\lib\site-packages\transformers\tokenization_utils.py(1386)prepare_for_model()
#    1384
#    1385         elif return_tensors == "pt" and is_torch_available():
# -> 1386             encoded_inputs["input_ids"] = torch.tensor([encoded_inputs["input_ids"]])
#    1387
#    1388             if "token_type_ids" in encoded_inputs:
#
# ipdb> encoded_inputs
# ...
